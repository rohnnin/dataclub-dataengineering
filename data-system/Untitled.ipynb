# %%
url = "https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/yellow_tripdata_2021-01.csv.gz"

# %%
import pandas as pd

# %%
import pandas as pantaloons

# %%
df = pantaloons.read_csv("https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/yellow_tripdata_2021-01.csv.gz");
# Out:
# /tmp/ipykernel_7166/3443405373.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pantaloons.read_csv("https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/yellow_tripdata_2021-01.csv.gz");

# %%
df.head()['trip_distance']
# Out:
# 0     2.10
# 1     0.20
# 2    14.70
# 3    10.60
# 4     4.94
# Name: trip_distance, dtype: float64

# %%
df['trip_distance' < 2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df['trip_distance' < 2]
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0       1.0  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1       1.0  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2       1.0  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3       1.0  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4       2.0  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10         1.0                  N           142            43
# 1           0.20         1.0                  N           238           151
# 2          14.70         1.0                  N           132           165
# 3          10.60         1.0                  N           138           132
# 4           4.94         1.0                  N            68            33
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
len(df['trip_distance'])
# Out:
# 1369765

# %%
len(df['trip_distance'])
# Out:
# 1369765

# %%
len(df['trip_distance']  < 2 )
# Out:
# 1369765

# %%
df['trip_distance'] < 2
# Out:
# 0          False
# 1           True
# 2          False
# 3          False
# 4          False
#            ...
# 1369760    False
# 1369761    False
# 1369762    False
# 1369763    False
# 1369764    False
# Name: trip_distance, Length: 1369765, dtype: bool

# %%
# Out:
# 0          False
# 1           True
# 2          False
# 3          False
# 4          False
#            ...
# 1369760    False
# 1369761    False
# 1369762    False
# 1369763    False
# 1369764    False
# Name: trip_distance, Length: 1369765, dtype: bool

# %%
dtype = {
    "VendorID": "Int64",
    "passenger_count": "Int64",
    "trip_distance": "float64",
    "RatecodeID": "Int64",
    "store_and_fwd_flag": "string",
    "PULocationID": "Int64",
    "DOLocationID": "Int64",
    "payment_type": "Int64",
    "fare_amount": "float64",
    "extra": "float64",
    "mta_tax": "float64",
    "tip_amount": "float64",
    "tolls_amount": "float64",
    "improvement_surcharge": "float64",
    "total_amount": "float64",
    "congestion_surcharge": "float64"
}

parse_dates = [
    "tpep_pickup_datetime",
    "tpep_dropoff_datetime"
]

df = pantaloons.read_csv(
    url,
    nrows=100,
    dtype=dtype,
    parse_dates=parse_dates
)

# %%
df['trip_distance']
# Out:
# 0      2.10
# 1      0.20
# 2     14.70
# 3     10.60
# 4      4.94
#       ...
# 95     4.13
# 96     4.12
# 97     2.22
# 98     7.11
# 99     1.61
# Name: trip_distance, Length: 100, dtype: float64

# %%
len(df['trip_distance'])
# Out:
# 100

# %%
dtype = {
    "VendorID": "Int64",
    "passenger_count": "Int64",
    "trip_distance": "float64",
    "RatecodeID": "Int64",
    "store_and_fwd_flag": "string",
    "PULocationID": "Int64",
    "DOLocationID": "Int64",
    "payment_type": "Int64",
    "fare_amount": "float64",
    "extra": "float64",
    "mta_tax": "float64",
    "tip_amount": "float64",
    "tolls_amount": "float64",
    "improvement_surcharge": "float64",
    "total_amount": "float64",
    "congestion_surcharge": "float64"
}

parse_dates = [
    "tpep_pickup_datetime",
    "tpep_dropoff_datetime"
]

df = pd.read_csv(
    url,
    nrows=100,
    dtype=dtype,
    parse_dates=parse_dates
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 25
#       1 dtype = {
#       2     "VendorID": "Int64",
#       3     "passenger_count": "Int64",
#    (...)     17     "congestion_surcharge": "float64"
#      18 }
#      20 parse_dates = [
#      21     "tpep_pickup_datetime",
#      22     "tpep_dropoff_datetime"
#      23 ]
# ---> 25 df = pd.read_csv(
#      26     url,
#      27     nrows=100,
#      28     dtype=dtype,
#      29     parse_dates=parse_dates
#      30 )
#
# NameError: name 'pd' is not defined

# %%
len(df['trip_distance']> 0.0 and df['trip_distance'] < 2.0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_7166/418196323.py in ?()
# ----> 1 len(df['trip_distance']> 0.0 and df['trip_distance'] < 2.0)
#
# /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/generic.py in ?(self)
#    1578     @final
#    1579     def __nonzero__(self) -> NoReturn:
# -> 1580         raise ValueError(
#    1581             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1582             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1583         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
count = ((df['trip_distance'] > 0.0) & (df['trip_distance'] < 2.0)).sum()

# %%
count = len(df[df['trip_distance'] < 2])

# %%
print(count)
# Out:
# 44

# %%
count = ((df['trip_distance'] > 0.0) & (df['trip_distance'] < 2.0)).sum()

# %%
print(count)
# Out:
# 42

# %%
df.min();

# %%
print(df['trip_distance'].min())
# Out:
# 0.0

# %%
len(df[df['trip_distance'] == 0.0])
# Out:
# 2

# %%
count = ((df['trip_distance'] > 0.0) & (df['trip_distance'] < 2.0)).sum()

# %%
print(count)
# Out:
# 42

# %%
# !wget https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-11.parquet
# Out:
# --2026-01-26 13:16:14--  https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-11.parquet
# Resolving d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net)... 18.239.115.86, 18.239.115.146, 18.239.115.4, ...
# Connecting to d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net)|18.239.115.86|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1164775 (1.1M) [binary/octet-stream]
# Saving to: ‘green_tripdata_2025-11.parquet’
#
# green_tripdata_2025 100%[===================>]   1.11M  --.-KB/s    in 0.02s
#
# 2026-01-26 13:16:14 (45.6 MB/s) - ‘green_tripdata_2025-11.parquet’ saved [1164775/1164775]

# %%
pandaframe = pd.read_parquet("./green_tripdata_2025-11.parquet");

# %%
pandaframe.head();

# %%
dfr = pandaframe.head();

# %%
print(dft);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 print(dft);
#
# NameError: name 'dft' is not defined

# %%
print(dfr);
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2025-11-01 00:34:48   2025-11-01 00:41:39                  N
# 1         2  2025-11-01 00:18:52   2025-11-01 00:24:27                  N
# 2         2  2025-11-01 01:03:14   2025-11-01 01:15:24                  N
# 3         2  2025-11-01 00:10:57   2025-11-01 00:24:53                  N
# 4         1  2025-11-01 00:03:48   2025-11-01 00:19:38                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            74            42              1.0           0.74
# 1         1.0            74            42              2.0           0.95
# 2         1.0            83           160              1.0           2.19
# 3         1.0           166           127              1.0           5.44
# 4         1.0           166           262              1.0           3.20
#
#    fare_amount  ...  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...

# %%
(dfr['trip_distance'] > 0.0) & (dfr['trip_distance'] < 2.0)
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# Name: trip_distance, dtype: bool

# %%
count = ((dfr['trip_distance'] > 0.0) & (dfr['trip_distance'] < 2.0)).sum()

# %%
print(count)
# Out:
# 2

# %%
len(dfr['trip_distance']);

# %%
print(len(dfr['trip_distance']));
# Out:
# 5

# %%
print(f"Total records: {len(dfr)}")
# Out:
# Total records: 5

# %%
# !wget https://github.com/DataTalksClub/nyc-tlc-data/releases/download/misc/taxi_zone_lookup.csv
# Out:
# --2026-01-26 13:28:00--  https://github.com/DataTalksClub/nyc-tlc-data/releases/download/misc/taxi_zone_lookup.csv
# Resolving github.com (github.com)... 20.207.73.82
# Connecting to github.com (github.com)|20.207.73.82|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
import pandas as pdframe

# %%
df = pdframe.read_csv(c);

# %%
print(df.head());
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
print(len(df))
# Out:
# 265

# %%
count(df['pep_pickup_datetime'] > '2025-11-01').sum();
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pep_pickup_datetime'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[60], line 1
# ...

# %%
df.head();

# %%
print(df.head());
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
df.to_csv('../green_tripdata_2025-11.csv', index=False)
print("Converted to CSV: ../green_tripdata_2025-11.csv")
# Out:
# Converted to CSV: ../green_tripdata_2025-11.csv

# %%
pcsv = df.read_csv("df.to_csv('../green_tripdata_2025-11.csv', index=False);
# Out:
#   Cell In[66], line 1
#     pcsv = df.read_csv("df.to_csv('../green_tripdata_2025-11.csv', index=False);
#                        ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
ls
# Out:
# Dockerfile                      nota.ipynb          pyproject.toml
# Untitled.ipynb                  nota.py             taxi_zone_lookup.csv
# green_tripdata_2025-11.parquet  pipeline-month.py*  uv.lock

# %%
df.read_csv("/workspaces/dataclub-dataengineering/data-system/taxi_zone_lookup.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_7166/3046296618.py in ?()
# ----> 1 df.read_csv("/workspaces/dataclub-dataengineering/data-system/taxi_zone_lookup.csv")
#
# /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'read_csv'

# %%
import pandas as pd

# %%
pd.read_csv("/workspaces/dataclub-dataengineering/data-system/taxi_zone_lookup.csv");

# %%
csv = pd.read_csv("/workspaces/dataclub-dataengineering/data-system/taxi_zone_lookup.csv");

# %%
print(csv.head());
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
print("Columns in DataFrame:", df.columns.tolist())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print("Columns in DataFrame:", df.columns.tolist())
#
# NameError: name 'df' is not defined

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
import pandas as dfPanda

# %%
csv = dfPanda.read_csv("//workspaces/dataclub-dataengineering/green_tripdata_2025-11.csv")

# %%
print(csv.head())
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
rcsv = dfPanda.read_csv("https://github.com/DataTalksClub/nyc-tlc-data/releases/download/misc/taxi_zone_lookup.csv")

# %%
print(rcsv.head())
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
print(csv.head())
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
# !wget https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-11.parquet
# Out:
# --2026-01-26 14:45:51--  https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-11.parquet
# Resolving d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net)... 18.239.115.4, 18.239.115.146, 18.239.115.213, ...
# Connecting to d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net)|18.239.115.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1164775 (1.1M) [binary/octet-stream]
# Saving to: ‘green_tripdata_2025-11.parquet.1’
#
# green_tripdata_2025 100%[===================>]   1.11M  --.-KB/s    in 0.02s
#
# 2026-01-26 14:45:51 (54.3 MB/s) - ‘green_tripdata_2025-11.parquet.1’ saved [1164775/1164775]

# %%
# !wget https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-11.parquet
# Out:
# --2026-01-26 14:47:17--  https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-11.parquet
# Resolving d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net)... 18.239.115.4, 18.239.115.146, 18.239.115.86, ...
# Connecting to d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net)|18.239.115.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1164775 (1.1M) [binary/octet-stream]
# Saving to: ‘green_tripdata_2025-11.parquet’
#
# green_tripdata_2025 100%[===================>]   1.11M  --.-KB/s    in 0.03s
#
# 2026-01-26 14:47:17 (33.1 MB/s) - ‘green_tripdata_2025-11.parquet’ saved [1164775/1164775]

# %%
# !wget https://github.com/DataTalksClub/nyc-tlc-data/releases/download/misc/taxi_zone_lookup.csv
# Out:
# --2026-01-26 14:48:14--  https://github.com/DataTalksClub/nyc-tlc-data/releases/download/misc/taxi_zone_lookup.csv
# Resolving github.com (github.com)... 20.207.73.82
# Connecting to github.com (github.com)|20.207.73.82|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
wget https://github.com/DataTalksClub/nyc-tlc-data/releases/download/misc/taxi_zone_lookup.csv
# Out:
#   Cell In[12], line 1
#     wget https://github.com/DataTalksClub/nyc-tlc-data/releases/download/misc/taxi_zone_lookup.csv
#          ^
# SyntaxError: invalid syntax

# %%
# !wget https://github.com/DataTalksClub/nyc-tlc-data/releases/download/misc/taxi_zone_lookup.csv
# Out:
# --2026-01-26 14:48:47--  https://github.com/DataTalksClub/nyc-tlc-data/releases/download/misc/taxi_zone_lookup.csv
# Resolving github.com (github.com)... 20.207.73.82
# Connecting to github.com (github.com)|20.207.73.82|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
import pandas as c

# %%
parquet = c.read_parquet("green_tripdata_2025-11.parquet")

# %%
csv = c.read_csv("taxi_zone_lookup.csv")

# %%
parquet.head();

# %%
prqcol = parquet.head();

# %%
csvcol = csv.head();

# %%
print(prqcol.head());
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2025-11-01 00:34:48   2025-11-01 00:41:39                  N
# 1         2  2025-11-01 00:18:52   2025-11-01 00:24:27                  N
# 2         2  2025-11-01 01:03:14   2025-11-01 01:15:24                  N
# 3         2  2025-11-01 00:10:57   2025-11-01 00:24:53                  N
# 4         1  2025-11-01 00:03:48   2025-11-01 00:19:38                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            74            42              1.0           0.74
# 1         1.0            74            42              2.0           0.95
# 2         1.0            83           160              1.0           2.19
# 3         1.0           166           127              1.0           5.44
# 4         1.0           166           262              1.0           3.20
#
#    fare_amount  ...  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 head(prqcol['trip_distance'])
#
# NameError: name 'head' is not defined

# %%
len(csvcol['trip_distance']  < 2 )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'trip_distance'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ...

# %%
print(prqcol['trip_distance'])
# Out:
# 0    0.74
# 1    0.95
# 2    2.19
# 3    5.44
# 4    3.20
# Name: trip_distance, dtype: float64

# %%
num_rows = len(prqcol)
# Out:
# 5

# %%
print(f"Number of rows: {num_rows}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 print(f"Number of rows: {num_rows}")
#
# NameError: name 'num_rows' is not defined

# %%
print(prqcol)
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2025-11-01 00:34:48   2025-11-01 00:41:39                  N
# 1         2  2025-11-01 00:18:52   2025-11-01 00:24:27                  N
# 2         2  2025-11-01 01:03:14   2025-11-01 01:15:24                  N
# 3         2  2025-11-01 00:10:57   2025-11-01 00:24:53                  N
# 4         1  2025-11-01 00:03:48   2025-11-01 00:19:38                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            74            42              1.0           0.74
# 1         1.0            74            42              2.0           0.95
# 2         1.0            83           160              1.0           2.19
# 3         1.0           166           127              1.0           5.44
# 4         1.0           166           262              1.0           3.20
#
#    fare_amount  ...  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...

# %%
import pandas as pd; df = pd.read_parquet('data-system/green_tripdata_2025-11.parquet'); print('Columns:', len(df.columns)); print('Rows:', len(df))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 import pandas as pd; df = pd.read_parquet('data-system/green_tripdata_2025-11.parquet'); print('Columns:', len(df.columns)); print('Rows:', len(df))
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/io/parquet.py:669, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     666     use_nullable_dtypes = False
#     667 check_dtype_backend(dtype_backend)
# --> 669 return impl.read(
#     670     path,
#     671     columns=columns,
#     672     filters=filters,
#     673     storage_options=storage_options,
#     674     use_nullable_dtypes=use_nullable_dtypes,
#     675     dtype_backend=dtype_backend,
#     676     filesystem=filesystem,
#     677     **kwargs,
#     678 )
#
# ...

# %%
import pandas as pd; df = pd.read_parquet('green_tripdata_2025-11.parquet'); print('Columns:', len(df.columns)); print('Rows:', len(df))
# Out:
# Columns: 21
# Rows: 46912

# %%
print(df.head())
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2025-11-01 00:34:48   2025-11-01 00:41:39                  N
# 1         2  2025-11-01 00:18:52   2025-11-01 00:24:27                  N
# 2         2  2025-11-01 01:03:14   2025-11-01 01:15:24                  N
# 3         2  2025-11-01 00:10:57   2025-11-01 00:24:53                  N
# 4         1  2025-11-01 00:03:48   2025-11-01 00:19:38                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            74            42              1.0           0.74
# 1         1.0            74            42              2.0           0.95
# 2         1.0            83           160              1.0           2.19
# 3         1.0           166           127              1.0           5.44
# 4         1.0           166           262              1.0           3.20
#
#    fare_amount  ...  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...

# %%
count = ((df['trip_distance'] > 0.0) & (df['trip_distance'] < 2.0)).sum()

# %%
print(count) &&
# Out:
# 20986

# %%
df['lpep_pickup_datetime'] = pd.to_datetime(df['lpep_pickup_datetime'])  
prqcol_november = df[prqcol['lpep_pickup_datetime'].dt.month == 11]
# Out:
# /tmp/ipykernel_7811/3474853373.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   prqcol_november = df[prqcol['lpep_pickup_datetime'].dt.month == 11]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[41], line 2
#       1 df['lpep_pickup_datetime'] = pd.to_datetime(df['lpep_pickup_datetime'])
# ----> 2 prqcol_november = df[prqcol['lpep_pickup_datetime'].dt.month == 11]
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/frame.py:4104, in DataFrame.__getitem__(self, key)
#    4102 # Do we have a (boolean) 1d indexer?
#    4103 if com.is_bool_indexer(key):
# -> 4104     return self._getitem_bool_array(key)
#    4106 # We are left with two options: a single key, and a collection of keys,
#    4107 # We interpret tuples as collections only for non-MultiIndex
# ...

# %%
import pandas as pd

# Ensure the date column is datetime
df['lpep_pickup_datetime'] = pd.to_datetime(df['lpep_pickup_datetime'])

# Filter for November 2025 and trip distance conditions
count = ((df['lpep_pickup_datetime'].dt.month == 11) & 
         (df['lpep_pickup_datetime'].dt.year == 2025) & 
         (df['trip_distance'] > 0.0) & 
         (df['trip_distance'] == 1.0)).sum()

print(f"Count of trips in November 2025 with 0 < trip_distance < 2: {count}")
# Out:
# Count of trips in November 2025 with 0 < trip_distance < 2: 259

# %%
df.cols_to_list()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_7811/3287908600.py in ?()
# ----> 1 df.cols_to_list()
#
# /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'cols_to_list'

# %%
df.columns.tolist()
# Out:
# ['VendorID',
#  'lpep_pickup_datetime',
#  'lpep_dropoff_datetime',
#  'store_and_fwd_flag',
#  'RatecodeID',
#  'PULocationID',
#  'DOLocationID',
#  'passenger_count',
#  'trip_distance',
#  'fare_amount',
#  'extra',
#  'mta_tax',
#  'tip_amount',
#  'tolls_amount',
#  'ehail_fee',
#  'improvement_surcharge',
#  'total_amount',
#  'payment_type',
#  'trip_type',
#  'congestion_surcharge',
#  'cbd_congestion_fee']

# %%
df[df['trip_distance'] < 100.0]['lpep_pickup_datetime']
# Out:
# 0       2025-11-01 00:34:48
# 1       2025-11-01 00:18:52
# 2       2025-11-01 01:03:14
# 3       2025-11-01 00:10:57
# 4       2025-11-01 00:03:48
#                 ...
# 46907   2025-11-30 19:58:34
# 46908   2025-11-30 19:34:00
# 46909   2025-11-30 21:46:46
# 46910   2025-11-30 21:00:00
# 46911   2025-11-30 23:26:00
# Name: lpep_pickup_datetime, Length: 46891, dtype: datetime64[us]

# %%
count = (df['trip_distance'] < 100.0)

# %%
print(count)
# Out:
# 46891

# %%
filtered_df = df[count]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: np.int64(46891)
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 1
# ...

# %%
 datatable = df[(df['trip_distance'] < 100.0)]

# %%
df[(df['trip_distance'] < 100.0)][trip_distance < 1.0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 df[(df['trip_distance'] < 100.0)][trip_distance < 1.0]
#
# NameError: name 'trip_distance' is not defined

# %%
df[(df['trip_distance'] < 100.0)]['trip_distance' < 1.0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 df[(df['trip_distance'] < 100.0)]['trip_distance' < 1.0]
#
# TypeError: '<' not supported between instances of 'str' and 'float'

# %%
df[(df['trip_distance'] < 100.0)]['trip_distance'] < 1.0]
# Out:
#   Cell In[67], line 1
#     df[(df['trip_distance'] < 100.0)]['trip_distance'] < 1.0]
#                                                             ^
# SyntaxError: unmatched ']'

# %%
datatable[datatable['trip_distance' < 1.0]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 datatable[datatable['trip_distance' < 1.0]]
#
# TypeError: '<' not supported between instances of 'str' and 'float'

# %%
datatables = datatable['trip_distance'].astype(float)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 datatables['trip_distance' < 1.0]
#
# TypeError: '<' not supported between instances of 'str' and 'float'

# %%
datatables.dtypes
# Out:
# dtype('float64')

# %%
datatables[datatables['trip_distance'] < 1.0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:175, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'trip_distance'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 datatables[datatables['trip_distance'] < 1.0]
#
# ...

# %%
type(datatables)
# Out:
# pandas.core.series.Series

# %%
Dtb = datatables.to_frame(name='trip-distance')

# %%
Dtb = datatables.to_frame()

# %%
Dtb[Dtb['trip_distance'] < 1.0]
# Out:
#        trip_distance
# 0               0.74
# 1               0.95
# 8               0.63
# 11              0.00
# 14              0.00
# ...              ...
# 46789           0.95
# 46809           0.80
# 46824           0.00
# 46854           0.79
# 46876           0.67
#
# [7750 rows x 1 columns]

# %%
Dtb[Dtb['trip_distance'] < 1.0].dtypes
# Out:
# trip_distance    float64
# dtype: object

# %%
Dtab = Dtb[Dtb['trip_distance'] < 100.0]

# %%
Dtab = Dtab[Dtab['trip-distance']].max()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'trip-distance'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[82], line 1
# ...

# %%
Dtab['trip_distance'].max()
# Out:
# np.float64(88.03)

# %%
print(Dtab['trip_distance'].max())
# Out:
# 88.03

# %%
print(df.head())
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2025-11-01 00:34:48   2025-11-01 00:41:39                  N
# 1         2  2025-11-01 00:18:52   2025-11-01 00:24:27                  N
# 2         2  2025-11-01 01:03:14   2025-11-01 01:15:24                  N
# 3         2  2025-11-01 00:10:57   2025-11-01 00:24:53                  N
# 4         1  2025-11-01 00:03:48   2025-11-01 00:19:38                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            74            42              1.0           0.74
# 1         1.0            74            42              2.0           0.95
# 2         1.0            83           160              1.0           2.19
# 3         1.0           166           127              1.0           5.44
# 4         1.0           166           262              1.0           3.20
#
#    fare_amount  ...  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...

# %%
df.len()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_7811/942532428.py in ?()
# ----> 1 df.len()
#
# /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'len'

# %%
len(df)
# Out:
# 46912

# %%
df.dtypes
# Out:
# VendorID                          int32
# lpep_pickup_datetime     datetime64[us]
# lpep_dropoff_datetime    datetime64[us]
# store_and_fwd_flag               object
# RatecodeID                      float64
# PULocationID                      int32
# DOLocationID                      int32
# passenger_count                 float64
# trip_distance                   float64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# ehail_fee                       float64
# improvement_surcharge           float64
# total_amount                    float64
# payment_type                    float64
# trip_type                       float64
# congestion_surcharge            float64
# cbd_congestion_fee              float64
# dtype: object

# %%
df[df['trip_distance'] == 88.03]
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 18867         2  2025-11-14 15:36:27   2025-11-14 18:40:48                  N
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 18867         4.0           130           265              2.0          88.03
#
#        fare_amount  ...  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 18867        610.6  ...      0.5         0.0           0.0        NaN
#
#        improvement_surcharge  total_amount  payment_type  trip_type  \
# 18867                    1.0         612.1           2.0        1.0
#
#        congestion_surcharge  cbd_congestion_fee
# 18867                   0.0                 0.0
#
# [1 rows x 21 columns]

# %%
df.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2025-11-01 00:34:48   2025-11-01 00:41:39                  N
# 1         2  2025-11-01 00:18:52   2025-11-01 00:24:27                  N
# 2         2  2025-11-01 01:03:14   2025-11-01 01:15:24                  N
# 3         2  2025-11-01 00:10:57   2025-11-01 00:24:53                  N
# 4         1  2025-11-01 00:03:48   2025-11-01 00:19:38                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            74            42              1.0           0.74
# 1         1.0            74            42              2.0           0.95
# 2         1.0            83           160              1.0           2.19
# 3         1.0           166           127              1.0           5.44
# 4         1.0           166           262              1.0           3.20
#
#    fare_amount  ...  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...

# %%
df['total_amount'].max()
# Out:
# np.float64(991.0)

# %%
maxvalue = df['total_amount'].max()

# %%
df[df['total_amount'] == 991.0]
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 21496         2  2025-11-16 13:35:13   2025-11-16 13:35:38                  N
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 21496         5.0            57            57              4.0           0.03
#
#        fare_amount  ...  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 21496        990.0  ...      0.0         0.0           0.0        NaN
#
#        improvement_surcharge  total_amount  payment_type  trip_type  \
# 21496                    1.0         991.0           2.0        1.0
#
#        congestion_surcharge  cbd_congestion_fee
# 21496                   0.0                 0.0
#
# [1 rows x 21 columns]

# %%
df.dtypes
# Out:
# VendorID                          int32
# lpep_pickup_datetime     datetime64[us]
# lpep_dropoff_datetime    datetime64[us]
# store_and_fwd_flag               object
# RatecodeID                      float64
# PULocationID                      int32
# DOLocationID                      int32
# passenger_count                 float64
# trip_distance                   float64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# ehail_fee                       float64
# improvement_surcharge           float64
# total_amount                    float64
# payment_type                    float64
# trip_type                       float64
# congestion_surcharge            float64
# cbd_congestion_fee              float64
# dtype: object

# %%
target_date = pd.to_datetime("2025-11-18").date()

filtered_df = df[df['lpep_pickup_datetime'].dt.date == pd.to_datetime(target_date).date()]

# %%
filtered_df[total_amount]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 filtered_df[total_amount]
#
# NameError: name 'total_amount' is not defined

# %%
filtered_df.dtypes
# Out:
# VendorID                          int32
# lpep_pickup_datetime     datetime64[us]
# lpep_dropoff_datetime    datetime64[us]
# store_and_fwd_flag               object
# RatecodeID                      float64
# PULocationID                      int32
# DOLocationID                      int32
# passenger_count                 float64
# trip_distance                   float64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# ehail_fee                       float64
# improvement_surcharge           float64
# total_amount                    float64
# payment_type                    float64
# trip_type                       float64
# congestion_surcharge            float64
# cbd_congestion_fee              float64
# dtype: object

# %%
filtered_df.to_string();

# %%
print(filtered_df.to_string());
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  improvement_surcharge  total_amount  payment_type  trip_type  congestion_surcharge  cbd_congestion_fee
# 22419         2  2025-11-18 08:07:00   2025-11-18 08:19:15                  N         1.0            74            75              1.0           1.40        12.10   0.00      0.5        3.40          0.00        NaN                    1.0         17.00           1.0        1.0                  0.00                0.00
# 22420         2  2025-11-18 08:19:54   2025-11-18 08:29:08                  N         1.0            75           236              1.0           1.33        10.00   0.00      0.5        2.85          0.00        NaN                    1.0         17.10           1.0        1.0                  2.75                0.00
# ...

# %%
summ = filtered_df['total_amount'].sum();

# %%
print(summ)
# Out:
# 45845.909999999996

# %%
filtered_dt['lpep_pickup_datetime']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 filtered_dt['lpep_pickup_datetime']
#
# NameError: name 'filtered_dt' is not defined

# %%
filtered_df['lpep_pickup_datetime']
# Out:
# 22419   2025-11-18 08:07:00
# 22420   2025-11-18 08:19:54
# 22421   2025-11-18 08:42:22
# 22528   2025-11-18 09:08:07
# 22529   2025-11-18 09:37:57
#                 ...
# 44825   2025-11-18 20:42:28
# 44826   2025-11-18 20:50:43
# 44827   2025-11-18 20:25:00
# 44828   2025-11-18 22:38:00
# 44829   2025-11-18 22:21:00
# Name: lpep_pickup_datetime, Length: 1773, dtype: datetime64[us]

# %%
df['date'] = filtered_df['lpep_pickup_datetime'].dt.date
target_date = df.groupby('date')['total_amount'].sum().idxmax()
fi_df = df[df['date'] == target_date]

print(fi_df)
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 22419         2  2025-11-18 08:07:00   2025-11-18 08:19:15                  N
# 22420         2  2025-11-18 08:19:54   2025-11-18 08:29:08                  N
# 22421         2  2025-11-18 08:42:22   2025-11-18 08:53:49                  N
# 22528         2  2025-11-18 09:08:07   2025-11-18 09:14:44                  N
# 22529         2  2025-11-18 09:37:57   2025-11-18 09:52:39                  N
# ...         ...                  ...                   ...                ...
# 44825         6  2025-11-18 20:42:28   2025-11-18 21:30:50               None
# 44826         6  2025-11-18 20:50:43   2025-11-18 22:03:03               None
# 44827         2  2025-11-18 20:25:00   2025-11-18 20:50:00               None
# 44828         2  2025-11-18 22:38:00   2025-11-18 22:47:00               None
# 44829         2  2025-11-18 22:21:00   2025-11-18 22:34:00               None
#
# ...

# %%
fi_df.dtypes
# Out:
# VendorID                          int32
# lpep_pickup_datetime     datetime64[us]
# lpep_dropoff_datetime    datetime64[us]
# store_and_fwd_flag               object
# RatecodeID                      float64
# PULocationID                      int32
# DOLocationID                      int32
# passenger_count                 float64
# trip_distance                   float64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# ehail_fee                       float64
# improvement_surcharge           float64
# total_amount                    float64
# payment_type                    float64
# trip_type                       float64
# congestion_surcharge            float64
# cbd_congestion_fee              float64
# date                             object
# dtype: object

# %%
rscv.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 rscv.head()
#
# NameError: name 'rscv' is not defined

# %%
rcsv.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
rsv.to_string()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 rsv.to_string()
#
# NameError: name 'rsv' is not defined

# %%
print(rcsv.to_string());
# Out:
#      LocationID        Borough                                           Zone service_zone
# 0             1            EWR                                 Newark Airport          EWR
# 1             2         Queens                                    Jamaica Bay    Boro Zone
# 2             3          Bronx                        Allerton/Pelham Gardens    Boro Zone
# 3             4      Manhattan                                  Alphabet City  Yellow Zone
# 4             5  Staten Island                                  Arden Heights    Boro Zone
# 5             6  Staten Island                        Arrochar/Fort Wadsworth    Boro Zone
# 6             7         Queens                                        Astoria    Boro Zone
# 7             8         Queens                                   Astoria Park    Boro Zone
# 8             9         Queens                                     Auburndale    Boro Zone
# ...

# %%
rsv.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[118], line 1
# ----> 1 rsv.dtypes
#
# NameError: name 'rsv' is not defined

# %%
print(rsv);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[119], line 1
# ----> 1 print(rsv);
#
# NameError: name 'rsv' is not defined

# %%
rcsv.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[120], line 1
# ----> 1 rcsv.dtypes()
#
# TypeError: 'Series' object is not callable

# %%
rcsv.dtype();
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_7811/953599693.py in ?()
# ----> 1 rcsv.dtype();
#
# /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
rcsv.head();

# %%
rcsv[rcsv['LocationID' == 57]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[123], line 1
# ...

# %%
rcsv[LocationID == 57].head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 rcsv[LocationID == 57].head()
#
# NameError: name 'LocationID' is not defined

# %%
rcsv[LocationID == 57]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[126], line 1
# ----> 1 rcsv[LocationID == 57]
#
# NameError: name 'LocationID' is not defined

# %%
rcsv.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
rcsv.columnstoList();
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_7811/2204712107.py in ?()
# ----> 1 rcsv.columnstoList();
#
# /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'columnstoList'

# %%
df[df['LocationID'] == 30]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'LocationID'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[129], line 1
# ...

# %%
rcsv.dtypes
# Out:
# LocationID       int64
# Borough         object
# Zone            object
# service_zone    object
# dtype: object

# %%
rcsv.columns.tolist()
# Out:
# ['LocationID', 'Borough', 'Zone', 'service_zone']

# %%
rcsv[rcsv['LocationID'] == 57]
# Out:
#     LocationID Borough    Zone service_zone
# 56          57  Queens  Corona    Boro Zone

# %%
zone_grouped = filtered_df.groupby('PULocationID')['total_amount'].sum()

# %%
largest_zone = zone_grouped.idxmax()   # gives the zone name/ID
largest_value = zone_grouped.max()     # gives the sum value

print("Pickup zone with largest total:", largest_zone, "Sum:", largest_value)
# Out:
# Pickup zone with largest total: 74 Sum: 9281.92

# %%
print(largest_zone)
# Out:
# 74

# %%
zone_df = rcsv[rcsv['Zone'] == largest_zone]

# %%
print(zone_df.head())
# Out:
# Empty DataFrame
# Columns: [LocationID, Borough, Zone, service_zone]
# Index: []

# %%
rcsv[rcsv[Location_ID] == 74]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[141], line 1
# ----> 1 rcsv[rcsv[Location_ID] == 74]
#
# NameError: name 'Location_ID' is not defined

# %%
rcsv[rcsv['LocationID'] == 74]
# Out:
#     LocationID    Borough               Zone service_zone
# 73          74  Manhattan  East Harlem North    Boro Zone

# %%
filtered_data[filtered_data == 74]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[143], line 1
# ----> 1 filtered_data[filtered_data == 74]
#
# NameError: name 'filtered_data' is not defined

# %%
filtered_data[LocationID == 74]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[144], line 1
# ----> 1 filtered_data[LocationID == 74]
#
# NameError: name 'filtered_data' is not defined

# %%
filtered_df['LocationID' == 74]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[147], line 1
# ...

# %%
filtered_df['LocationID' == 74]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[148], line 1
# ...

# %%
df_filter = filtered_df[filtered_df['PULocationID'] == 74]

# %%
filtered_nov = df_filter[df_filter['lpep_pickup_datetime'].dt.month == 11]

# %%
filtered_nov.dtypes
# Out:
# VendorID                          int32
# lpep_pickup_datetime     datetime64[us]
# lpep_dropoff_datetime    datetime64[us]
# store_and_fwd_flag               object
# RatecodeID                      float64
# PULocationID                      int32
# DOLocationID                      int32
# passenger_count                 float64
# trip_distance                   float64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# ehail_fee                       float64
# improvement_surcharge           float64
# total_amount                    float64
# payment_type                    float64
# trip_type                       float64
# congestion_surcharge            float64
# cbd_congestion_fee              float64
# dtype: object

# %%
largest_trip_df = filtered_nov.loc[[filtered_nov['trip_distance'].idxmax()]]

# %%
largeest_trip_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[156], line 1
# ----> 1 largeest_trip_df.head()
#
# NameError: name 'largeest_trip_df' is not defined
