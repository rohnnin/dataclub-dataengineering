# %%
import pandas as pd

# %%
pd.__file__
# Out:
# '/usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/__init__.py'

# %%
# Load the Parquet file into a DataFrame
df = pd.read_parquet('../green_tripdata_2025-11.parquet')

# Check the total number of records
print(f"Total records: {len(df)}")

# Convert to CSV
df.to_csv('../green_tripdata_2025-11.csv', index=False)
print("Converted to CSV: ../green_tripdata_2025-11.csv")

# Display specific columns
print("Columns in DataFrame:", df.columns.tolist())
print("\nFirst 5 rows of lpep_pickup_datetime and trip_distance:")
df[['lpep_pickup_datetime', 'trip_distance']].head()
