# %%
python --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 python --version
#
# NameError: name 'python' is not defined

# %%
python -version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 python -version
#
# NameError: name 'python' is not defined

# %%
clear()

# %%
python -version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 python -version
#
# NameError: name 'python' is not defined

# %%
exit()
